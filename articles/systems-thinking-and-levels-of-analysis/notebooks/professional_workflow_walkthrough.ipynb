# %% [markdown]
# # Systems Thinking and Levels of Analysis Professional Workflow Walkthrough
# Run `python/run_professional_workflow.py`, then inspect the generated outputs.

# %%
from pathlib import Path
import pandas as pd
article_dir = Path.cwd()
pd.read_csv(article_dir / 'outputs/tables/professional_timeseries.csv').head()
