# %% [markdown]
# # System Archetypes and Recurring Patterns
#
# Notebook placeholder for exploring archetype diagnostics, behavior-over-time graphs, and scenario comparison with synthetic data.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd().parents[0]
data = root / 'data' / 'synthetic_archetypes.csv'
pd.read_csv(data).head()
