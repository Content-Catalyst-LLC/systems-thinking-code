# %% [markdown]
# # Commons Systems Walkthrough
#
# Placeholder notebook for tragedy-of-the-commons and shared resource system modeling. Run the Python scripts in `python/` to generate output tables.
